# %%
## Fix data

from datasets import load_dataset
import pandas as pd
version = 5
file = f'L3_data{version}.csv'
data  = load_dataset("csv", data_files = file) #Load dataset
data = pd.DataFrame(data['train'])
data =data.drop(columns = "Unnamed: 0")
display(data)
# Out:
#     Answer                                         Raw_Answer  Confidence  \
# 0      Yes   <a>Yes, very uncertain <b>\n\nPassage: The Gr...         0.5
# 1      Yes   <a>Yes, very certain <b>\n\nPassage: The Unit...         0.9
# 2      Yes   <a>Yes, very certain <b>\n\nPassage: The Grea...         0.9
# 3      Yes   <a>Yes, very certain <b>\n\nPassage: The Grea...         0.9
# 4      Yes   <a>Yes, very certain <b>\n\nPassage: The Unit...         0.9
# ..     ...                                                ...         ...
# 175    Yes   <a>Yes, very certain <b>\n\nPassage: The Unit...         0.9
# 176    Yes   <a>Yes, very certain <b>\n\nPassage: The Unit...         0.9
# 177    Yes   <a>Yes, very certain <b>\n\nPassage: The Unit...         0.9
# 178     No   <a>No, very uncertain <b>\n\nPassage: The Uni...         0.5
# 179     No   <a>No, very certain <b>\n\nPassage: The Unite...         0.9
#
#     Stated_Confidence  Yes_Prob   No_Prob  Prob_Score  Correct_Answer  Score
# ...

# %%
## Replace values

## Find N
N = data.shape[0]

for i in range(N):
    val = data.loc[i, "Confidence"]
    
    val = val / 100
    data.loc[i, "Confidence"] = val



display(data)
# Out:
# /tmp/SLURM_24624460/ipykernel_2147/2240688206.py:10: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '0.6' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data.loc[i, "Confidence"] = val
#     Answer                                         Raw_Answer  Confidence  \
# 0       No   No, 60%\nExplanation: Ethanol is a renewable ...         0.6
# 1       No   No, 60%\nExplanation: The passage states that...         0.6
# 2       No   No, 60%\nExplanation: Phantom pain sensations...         0.6
# 3       No   No, 60%\nExplanation: The ride is not a rolle...         0.6
# 4       No   No, 60%\nExplanation: Barq's is not a Pepsi p...         0.6
# ..     ...                                                ...         ...
# 464    Yes   Yes, 80%\nExplanation: There is a new Hallowe...         0.8
# 465     No   No, 60%\nExplanation: The two names are diffe...         0.6
# ...

# %%
new_file_name = f'L3_data{version}.csv'
data.to_csv(new_file_name)
